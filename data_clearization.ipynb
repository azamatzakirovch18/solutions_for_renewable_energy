# %%
import pandas as pd

df = pd.read_csv('1 copy.csv')
df
# Out:
#         Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 0           USA  2011       Solar      85404.690027              5549.794323
# 1     Australia  2008  Geothermal      22205.069382             43211.593798
# 2        Canada  2013     Biomass      94102.732038              6139.117212
# 3         Japan  2010     Biomass      88771.932910             40323.639260
# 4         China  2018       Solar      93288.408581             30755.403056
# ...         ...   ...         ...               ...                      ...
# 2495      Japan  2023       Solar      40091.199325             46650.085012
# 2496  Australia  2017       Hydro       9454.189177             28506.752159
# 2497      India  2022  Geothermal      94329.590380             22757.496947
# 2498      China  2000     Biomass      66206.311515              3530.005331
# 2499     France  2010       Hydro      13035.595344             22890.620016
#
# ...

# %% [markdown]
# firstly I should see how many missed values i have ?

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Wow, that's amazing. There's no any kind of missed data. Actually, are there any columns that have the wrong type ?

# %%
df
# Out:
#         Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 0           USA  2011       Solar      85404.690027              5549.794323
# 146      Brazil  2011       Solar      25460.772329             17997.210988
# 248      Brazil  2011       Solar      37185.693759              5972.319209
# 380      Brazil  2011       Solar      42401.948038             41722.029337
# 450   Australia  2011       Solar       8250.397486             36886.646843
# 572   Australia  2011       Solar      48036.835913             15969.164248
# 784      France  2011       Solar      31315.665129             49879.333577
# 805      Canada  2011       Solar      59406.910141             43067.854982
# 814      France  2011       Solar      26214.465679             42776.769127
# 838     Germany  2011       Solar       4668.935962             30640.211540
# 1061     Russia  2011       Solar      45962.250436             36452.551664
# ...

# %% [markdown]
# Yes. Exist and I need to change them to correct data type!
#
# they are:
#
#     to_int = ["Investment (USD)","GDP","R&D Expenditure","Energy Subsidies","International Aid for Renewables"]
#
#     to_bool = ["Government Policies","Renewable Energy Targets","Energy Efficiency Programs","Energy Market Liberalization","Technology Transfer Agreements","Renewable Energy Education Programs","Natural Disasters","Public-Private Partnership in Energy","Regional Renewable Energy Cooperation"]

# %%
to_int = ["Investments (USD)","GDP","R&D Expenditure","Energy Subsidies","International Aid for Renewables"]
    
to_bool = ["Government Policies","Renewable Energy Targets","Energy Efficiency Programs","Energy Market Liberalization","Technology Transfer Agreements","Renewable Energy Education Programs","Natural Disasters","Public-Private Partnerships in Energy","Regional Renewable Energy Cooperation"]

# %%
df[to_int] = df[to_int].astype(int)
df[to_bool] = df[to_bool].astype(bool)
# Out:
# /var/folders/mb/vw_lpkv97jld5l8j9wt_vx_m0000gn/T/ipykernel_96379/1654038770.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[to_int] = df[to_int].astype(int)
# /var/folders/mb/vw_lpkv97jld5l8j9wt_vx_m0000gn/T/ipykernel_96379/1654038770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[to_bool] = df[to_bool].astype(bool)

# %%
df[to_bool]
# Out:
#       Government Policies  Renewable Energy Targets  \
# 0                    True                      True
# 146                  True                      True
# 248                 False                      True
# 380                  True                      True
# 450                 False                     False
# 572                 False                      True
# 784                 False                     False
# 805                 False                      True
# 814                 False                     False
# 838                  True                     False
# 1061                False                     False
# 1085                 True                      True
# 1296                False                      True
# 1306                False                     False
# 1413                False                     False
# 1429                False                     False
# 1504                 True                     False
# ...

# %%
df[to_int]
# Out:
#       Investments (USD)              GDP  R&D Expenditure  Energy Subsidies  \
# 0            5604124938  177527818919196       8676561392         168820814
# 146           801360121  183542353320079        138059933         391832484
# 248          1755931779    1909889960357       1012978096         310302443
# 380          6184476843   25326056775973       5955593821         588109668
# 450          9153566535   15748251075508       1212130586         798132713
# 572          4134075102  174793923359362       3217086667         468404046
# 784          4339394036   42500963886409       4361315204         446482285
# 805          1187444338  154648644605608       2969483684         470734209
# 814          3473815729   11370122210184       7290904922         307560459
# 838           426748083  184298969773058       8106163880         828393198
# 1061         2622612188  121276028070906       8059889587         412036373
# ...

# %% [markdown]
# everything is great !
#
# Data cleaning is finished. Next step is make dashboard and find problems to eng give solutions !

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Energy Type', 'Production (GWh)',
#        'Installed Capacity (MW)', 'Investments (USD)', 'Population', 'GDP',
#        'Energy Consumption', 'Energy Exports', 'Energy Imports',
#        'CO2 Emissions', 'Renewable Energy Jobs', 'Government Policies',
#        'R&D Expenditure', 'Renewable Energy Targets',
#        'Average Annual Temperature', 'Annual Rainfall', 'Solar Irradiance',
#        'Wind Speed', 'Hydro Potential', 'Geothermal Potential',
#        'Biomass Availability', 'Energy Storage Capacity',
#        'Grid Integration Capability', 'Electricity Prices', 'Energy Subsidies',
#        'International Aid for Renewables', 'Public Awareness',
#        'Energy Efficiency Programs', 'Urbanization Rate',
#        'Industrialization Rate', 'Energy Market Liberalization',
#        'Renewable Energy Patents', 'Educational Level',
#        'Technology Transfer Agreements', 'Renewable Energy Education Programs',
# ...

# %%
df["Energy Type"].unique()
# Out:
# array(['Solar'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Country                                    0
# Year                                       0
# Energy Type                                0
# Production (GWh)                           0
# Installed Capacity (MW)                    0
# Investments (USD)                          0
# Population                                 0
# GDP                                        0
# Energy Consumption                         0
# Energy Exports                             0
# Energy Imports                             0
# CO2 Emissions                              0
# Renewable Energy Jobs                      0
# Government Policies                        0
# R&D Expenditure                            0
# Renewable Energy Targets                   0
# Average Annual Temperature                 0
# Annual Rainfall                            0
# Solar Irradiance                           0
# Wind Speed                                 0
# Hydro Potential                            0
# ...

# %%
# Group 1: Technical and Infrastructure Capacity
technical_infrastructure_capacity = [
    "Energy Storage Capacity", 
    "Grid Integration Capability", 
    "Energy Market Liberalization"
]

# Group 2: Economic and Financial Aspects
economic_financial_aspects = [
    "Electricity Prices", 
    "Energy Subsidies", 
    "International Aid for Renewables", 
    "Export Incentives for Energy Equipment", 
    "Import Tariffs on Energy Equipment", 
    "Economic Freedom Index", 
    "Ease of Doing Business"
]

# Group 3: Innovation and Technology
innovation_technology = [
    "Renewable Energy Patents", 
    "Technology Transfer Agreements", 
    "Local Manufacturing Capacity", 
    "Innovation Index"
]

# Group 4: Education and Awareness
education_awareness = [
    "Public Awareness", 
    "Renewable Energy Education Programs", 
    "Educational Level"
]

# Group 5: Regulatory and Legal Framework
regulatory_legal_framework = [
    "Political Stability", 
    "Corruption Perception Index", 
    "Regulatory Quality", 
    "Rule of Law", 
    "Control of Corruption"
]

# Group 6: Environmental Factors
environmental_factors = [
    "Natural Disasters", 
    "Proportion of Energy from Renewables"
]

# Group 7: Social and Industrial Development
social_industrial_development = [
    "Urbanization Rate", 
    "Industrialization Rate", 
    "Energy Sector Workforce", 
    "Public-Private Partnerships in Energy"
]

# Group 8: Policy and Program Initiatives
policy_program_initiatives = [
    "Energy Efficiency Programs", 
    "Public-Private Partnerships in Energy", 
    "Regional Renewable Energy Cooperation"
]

# Group 9: Research and Institutions
research_institutions = [
    "Number of Research Institutions"
]
